# %%
# import the necessary libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

import tensorflow as tf 
from tensorflow import keras
from keras import layers

import random

# Set random seeds for reproducibility
seed = 22
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('auto-mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.shape

# 398 rows 9 columns
# Out:
# (398, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# Check the data types
df.dtypes.value_counts()
# Out:
# int64      4
# float64    3
# object     2
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Categorical columns
cat_col = [col for col in df.columns if df[col].dtype == 'object']
print('Categorical columns :',cat_col)
# Numerical columns
num_col = [col for col in df.columns if df[col].dtype != 'object']
print('Numerical columns :',num_col)
# Out:
# Categorical columns : ['horsepower', 'car name']
# Numerical columns : ['mpg', 'cylinders', 'displacement', 'weight', 'acceleration', 'model year', 'origin']

# %%
# Deal with categorical features
df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       94
# weight          351
# acceleration     95
# model year       13
# origin            3
# car name        305
# dtype: int64

# %%
df['horsepower'].unique() # notice the ?
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
# Drop rows with ?
print(df.shape)
df = df[df['horsepower'] != '?']
print(df.shape)
# Out:
# (398, 9)
# (392, 9)

# %%
df.dtypes

# horsepower is still object
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
df['horsepower'] = df['horsepower'].astype(int)

# %%
df.describe(include="all")
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   392.000000  392.000000    392.000000  392.000000   392.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.445918    5.471939    194.411990  104.469388  2977.584184
# std       7.805007    1.705783    104.644004   38.491160   849.402560
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%      22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%      29.000000    8.000000    275.750000  126.000000  3614.750000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration  model year      origin     car name
# count     392.000000  392.000000  392.000000          392
# unique           NaN         NaN         NaN          301
# top              NaN         NaN         NaN  amc matador
# freq             NaN         NaN         NaN            5
# mean       15.541327   75.979592    1.576531          NaN
# std         2.758864    3.683737    0.805518          NaN
# min         8.000000   70.000000    1.000000          NaN
# 25%        13.775000   73.000000    1.000000          NaN
# 50%        15.500000   76.000000    1.000000          NaN
# 75%        17.025000   79.000000    2.000000          NaN
# max        24.800000   82.000000    3.000000          NaN

# %%
# create df for numerical col only
num_df = df.select_dtypes(include=['number'])
num_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
# Check for outliers

# Create a subplot with num_df rows and 1 column
fig, axs = plt.subplots(len(num_df.columns), 1, dpi=95, figsize=(6,13))

# Loop through the columns and create box plots
i = 0
for col in num_df:
    axs[i].boxplot(df[col], vert=False)  # Create horizontal box plot
    axs[i].set_ylabel(col)               # Label each plot with column name
    i += 1

plt.show()

# %%
# Drop Outliers

# Identify the 1st (Q1) and 3rd (Q3) quartiles
q1, q3 = np.percentile(df['horsepower'], [25, 75])
# Calculate the Interquartile Range (IQR)
iqr = q3 - q1
# Calculate the lower and upper bounds for detecting outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers from the DataFrame
clean_data = df[(df['horsepower'] >= lower_bound) & (df['horsepower'] <= upper_bound)]
# Print the number of outliers removed
print(f"Original dataset size: {len(df)}")
print(f"Clean dataset size: {len(clean_data)}")

# Identify the 1st (Q1) and 3rd (Q3) quartiles
q1, q3 = np.percentile(df['acceleration'], [25, 75])
# Calculate the Interquartile Range (IQR)
iqr = q3 - q1
# Calculate the lower and upper bounds for detecting outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers from the DataFrame
clean_data = clean_data[(clean_data['acceleration'] >= lower_bound) & (clean_data['acceleration'] <= upper_bound)]
# Print the number of outliers removed
print(f"Clean dataset size: {len(clean_data)}")

clean_data.shape
# Out:
# Original dataset size: 392
# Clean dataset size: 382
# Clean dataset size: 372
# (372, 9)

# %%
# check outliers for acceleration and horsepower
fig, axs = plt.subplots(2, 1, dpi=95, figsize=(6,4))

axs[0].boxplot(clean_data["horsepower"], vert=False)  # Create horizontal box plot
axs[0].set_ylabel("horsepower")               # Label each plot with column name

axs[1].boxplot(clean_data["acceleration"], vert=False)  # Create horizontal box plot
axs[1].set_ylabel("acceleration")               # Label each plot with column name


plt.show()

# %%
# create num df from clean data for correlation
num_df_clean = clean_data.select_dtypes(include=['number'])
num_df_clean.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
# Correlation
corr = num_df_clean.corr() 
 
plt.figure(dpi=130, figsize=(5,2))
sns.heatmap(corr>0.9, annot=True, fmt='.2f', cbar=True, linewidths=0.5)
plt.show()

# 0-False 1-True

# %%
# drop displacement as it is highly correlated
clean_data.drop('displacement',axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

features = clean_data.drop(['mpg', 'car name'], axis=1)   #drop carname
target = clean_data['mpg'].values

X_train, X_test, Y_train, Y_test = train_test_split(features, target,
									test_size=0.2,
									random_state=22)

# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((297, 6), (75, 6))

# %%
# Data Input Pipeline

AUTO = tf.data.experimental.AUTOTUNE	# automatically tune the process

train_ds = (
	tf.data.Dataset
	.from_tensor_slices((X_train_scaled, Y_train)) # create a training dataset
	.batch(32) # batch size no 32
	.prefetch(AUTO) # automatically tune prefetching
)

test_ds = (
	tf.data.Dataset
	.from_tensor_slices((X_test_scaled, Y_test))
	.batch(32)
	.prefetch(AUTO)
)

# Batch size is no of data points passed through the model
# Model performs 32 samples at a time, then updates after each sample
# Eg data of 10k samples, then for one epoch model performs 10k/32=312 updatess

# %%
# Model Architecture
# Define a neural network using TensorFlow's Keras Sequential API

# Initialize the Sequential model
model = keras.Sequential([

    # First Dense layer with 256 neurons, ReLU activation, and input shape of 6 features
    layers.Dense(256, activation='relu', input_shape=[6]),  
    
    # Apply Batch Normalization, normalize inputs in each layer to stabilize training
    layers.BatchNormalization(),
    
    # Dropout layer, 30% of neurons are dropped set to 0 to prevent overfitting
    # Improve generalization on unseen data.
    layers.Dropout(0.3),
    
    # Second Dense layer with 256 neurons and ReLU activation
    layers.Dense(256, activation='relu'),

    # Apply another Batch Normalization after the second Dense layer
    layers.BatchNormalization(),
    
    # Dropout layer, 30% of neurons are dropped set to 0 to prevent overfitting
    # Improve generalization on unseen data.
    layers.Dropout(0.3),

    # Third Dense layer with 256 neurons, ReLU activation, and input shape of 6 features
    layers.Dense(256, activation='relu', input_shape=[6]),  
    
    # Apply Batch Normalization, normalize inputs in each layer to stabilize training
    layers.BatchNormalization(),

    # Output Dense layer with 1 neuron and ReLU activation
    # ReLU here ensures the output is non-negative
    layers.Dense(1, activation='relu')  
])

# %%
# Compile the model with Adam optimizer and a learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3, decay_steps=10000, decay_rate=0.9)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
	loss='mae',			# Mean Absolute Error is loss function used for training
	metrics=['mape']	# Mean Absolute Percentage Error as a metric to evaluate model accuracy
)

# %%
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_31 (Dense)                │ (None, 256)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 136,705 (534.00 KB)
#  Trainable params: 135,169 (528.00 KB)
#  Non-trainable params: 1,536 (6.00 KB)

# %% [markdown]
# + sequential_4
# The 4th version of a sequential model used in this session
# + dense layer fully connected layer
# Output, outputs layer with 256 neurons
# None means batch size is flexible, depends on input data
# `param=(input x units)+biases` (6×256)+256=1,792
# + batch normalization
# (256x2)=512 for scaling+512 for shifting=1,024
# + dense layer 2
# `param=(input x units)+biases` (256×256)+256=65,792
# + dropout layer
# No parameters are learned in the dropout layer
# + dense layer
# Only 1 output
# `param=(input x units)+biases` (256×1)+1=257

# %%
# Model Training
history = model.fit(train_ds,
					epochs=300,              # how many times the model will go through the entire dataset
					validation_data=test_ds) # dataset to evaluate performance after each epoch
# Out:
# Epoch 1/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 21.8586 - mape: 94.6920 - val_loss: 23.9128 - val_mape: 97.5147
# Epoch 2/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 16.7714 - mape: 77.1272 - val_loss: 22.4446 - val_mape: 92.5772
# Epoch 3/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.8526 - mape: 66.7238 - val_loss: 20.6497 - val_mape: 86.5431
# Epoch 4/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.9498 - mape: 59.8753 - val_loss: 18.8269 - val_mape: 80.1483
# Epoch 5/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.8590 - mape: 55.7089 - val_loss: 16.9361 - val_mape: 73.3274
# Epoch 6/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.3578 - mape: 54.0064 - val_loss: 14.9440 - val_mape: 65.8410
# Epoch 7/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9364 - mape: 52.2770 - val_loss: 12.7226 - val_mape: 56.8092
# Epoch 8/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4414 - mape: 50.1246 - val_loss: 10.5545 - val_mape: 47.6839
# Epoch 9/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2193 - mape: 49.0529 - val_loss: 8.6624 - val_mape: 39.6572
# Epoch 10/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6830 - mape: 46.3606 - val_loss: 7.0749 - val_mape: 33.4756
# Epoch 11/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2643 - mape: 44.2325 - val_loss: 6.5651 - val_mape: 32.9690
# Epoch 12/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1477 - mape: 43.5906 - val_loss: 6.5967 - val_mape: 34.1248
# Epoch 13/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9599 - mape: 43.0207 - val_loss: 6.6133 - val_mape: 34.6071
# Epoch 14/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8135 - mape: 42.1003 - val_loss: 6.7544 - val_mape: 35.3472
# Epoch 15/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7963 - mape: 41.8992 - val_loss: 7.0636 - val_mape: 37.0578
# Epoch 16/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8103 - mape: 41.7571 - val_loss: 6.7388 - val_mape: 35.3561
# Epoch 17/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7059 - mape: 41.3741 - val_loss: 6.9106 - val_mape: 36.3886
# Epoch 18/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6988 - mape: 41.4213 - val_loss: 6.6900 - val_mape: 35.0696
# Epoch 19/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4460 - mape: 40.3363 - val_loss: 6.7232 - val_mape: 35.1639
# Epoch 20/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4779 - mape: 40.3566 - val_loss: 6.7044 - val_mape: 35.0145
# Epoch 21/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5571 - mape: 40.6688 - val_loss: 6.6957 - val_mape: 34.8586
# Epoch 22/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5137 - mape: 40.5072 - val_loss: 6.4982 - val_mape: 33.7694
# Epoch 23/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5392 - mape: 40.6741 - val_loss: 6.4510 - val_mape: 33.5376
# Epoch 24/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3076 - mape: 39.6105 - val_loss: 6.3554 - val_mape: 32.9214
# Epoch 25/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3299 - mape: 39.6526 - val_loss: 6.2832 - val_mape: 32.4571
# Epoch 26/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3829 - mape: 39.6816 - val_loss: 6.3308 - val_mape: 32.4880
# Epoch 27/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1416 - mape: 38.7969 - val_loss: 6.2277 - val_mape: 32.1165
# Epoch 28/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3032 - mape: 39.4222 - val_loss: 6.3076 - val_mape: 32.7031
# Epoch 29/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1497 - mape: 38.8333 - val_loss: 6.0520 - val_mape: 31.8225
# Epoch 30/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1863 - mape: 38.7409 - val_loss: 6.0718 - val_mape: 31.9350
# Epoch 31/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0917 - mape: 38.4296 - val_loss: 6.0182 - val_mape: 31.9172
# Epoch 32/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8837 - mape: 37.4216 - val_loss: 5.8525 - val_mape: 31.3343
# Epoch 33/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6143 - mape: 36.2439 - val_loss: 5.8313 - val_mape: 31.5305
# Epoch 34/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7572 - mape: 36.9284 - val_loss: 5.7198 - val_mape: 30.9741
# Epoch 35/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4799 - mape: 35.8000 - val_loss: 5.4024 - val_mape: 29.5220
# Epoch 36/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3511 - mape: 34.7771 - val_loss: 5.6296 - val_mape: 30.5383
# Epoch 37/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0454 - mape: 33.3100 - val_loss: 5.3994 - val_mape: 29.2273
# Epoch 38/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2659 - mape: 34.3296 - val_loss: 5.3231 - val_mape: 28.6620
# Epoch 39/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0356 - mape: 33.3111 - val_loss: 5.1984 - val_mape: 28.2498
# Epoch 40/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9633 - mape: 32.7540 - val_loss: 5.1596 - val_mape: 27.7681
# Epoch 41/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0502 - mape: 33.1829 - val_loss: 4.9498 - val_mape: 27.0714
# Epoch 42/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1222 - mape: 33.3369 - val_loss: 4.9109 - val_mape: 26.7718
# Epoch 43/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8414 - mape: 32.2563 - val_loss: 4.7517 - val_mape: 25.8642
# Epoch 44/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7355 - mape: 31.2942 - val_loss: 4.6707 - val_mape: 25.5333
# Epoch 45/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8340 - mape: 31.6393 - val_loss: 4.5702 - val_mape: 25.1074
# Epoch 46/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7443 - mape: 31.4442 - val_loss: 4.7805 - val_mape: 25.8855
# Epoch 47/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8626 - mape: 32.2473 - val_loss: 4.4848 - val_mape: 24.4559
# Epoch 48/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6869 - mape: 31.0617 - val_loss: 4.4279 - val_mape: 24.0738
# Epoch 49/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4273 - mape: 29.7200 - val_loss: 4.3737 - val_mape: 23.5737
# Epoch 50/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5180 - mape: 30.0713 - val_loss: 4.5541 - val_mape: 24.2501
# Epoch 51/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5666 - mape: 30.5690 - val_loss: 4.5085 - val_mape: 24.1868
# Epoch 52/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6724 - mape: 30.7059 - val_loss: 4.2783 - val_mape: 23.2639
# Epoch 53/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4446 - mape: 30.1013 - val_loss: 4.2930 - val_mape: 23.0559
# Epoch 54/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1907 - mape: 28.6386 - val_loss: 4.4586 - val_mape: 23.5338
# Epoch 55/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3070 - mape: 29.1100 - val_loss: 4.2238 - val_mape: 22.2466
# Epoch 56/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3364 - mape: 29.0533 - val_loss: 4.3356 - val_mape: 23.0049
# Epoch 57/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2820 - mape: 29.0236 - val_loss: 4.3004 - val_mape: 22.6005
# Epoch 58/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1751 - mape: 28.5122 - val_loss: 3.9469 - val_mape: 20.6767
# Epoch 59/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1512 - mape: 28.1348 - val_loss: 3.9622 - val_mape: 20.3729
# Epoch 60/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0787 - mape: 27.6761 - val_loss: 3.9225 - val_mape: 19.9457
# Epoch 61/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2695 - mape: 28.5349 - val_loss: 3.9039 - val_mape: 20.1093
# Epoch 62/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9809 - mape: 27.0634 - val_loss: 3.9031 - val_mape: 20.1174
# Epoch 63/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9121 - mape: 26.7210 - val_loss: 3.9834 - val_mape: 20.1178
# Epoch 64/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0116 - mape: 26.9097 - val_loss: 4.1942 - val_mape: 20.7382
# Epoch 65/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9520 - mape: 26.5129 - val_loss: 4.0628 - val_mape: 20.2507
# Epoch 66/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7198 - mape: 25.5629 - val_loss: 3.6691 - val_mape: 18.4226
# Epoch 67/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7250 - mape: 25.0742 - val_loss: 3.3254 - val_mape: 16.6022
# Epoch 68/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6023 - mape: 24.5110 - val_loss: 3.1711 - val_mape: 16.1647
# Epoch 69/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6325 - mape: 24.9358 - val_loss: 3.5145 - val_mape: 17.8321
# Epoch 70/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6205 - mape: 24.4288 - val_loss: 3.3414 - val_mape: 17.0600
# Epoch 71/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4829 - mape: 23.9489 - val_loss: 3.0141 - val_mape: 15.3558
# Epoch 72/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.8602 - mape: 25.3244 - val_loss: 3.3024 - val_mape: 16.6086
# Epoch 73/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4082 - mape: 23.3536 - val_loss: 3.4287 - val_mape: 17.3495
# Epoch 74/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2872 - mape: 23.2168 - val_loss: 2.9261 - val_mape: 14.4432
# Epoch 75/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3380 - mape: 22.5595 - val_loss: 2.9050 - val_mape: 14.6939
# Epoch 76/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4256 - mape: 23.1025 - val_loss: 2.9679 - val_mape: 15.0723
# Epoch 77/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4034 - mape: 23.5338 - val_loss: 2.9271 - val_mape: 14.8726
# Epoch 78/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4872 - mape: 23.5080 - val_loss: 2.7005 - val_mape: 13.7454
# Epoch 79/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3646 - mape: 22.9933 - val_loss: 2.7169 - val_mape: 13.6585
# Epoch 80/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9639 - mape: 21.0387 - val_loss: 2.7941 - val_mape: 14.1842
# Epoch 81/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9881 - mape: 21.6511 - val_loss: 2.8692 - val_mape: 14.6910
# Epoch 82/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1449 - mape: 22.5318 - val_loss: 2.4863 - val_mape: 12.2196
# Epoch 83/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0331 - mape: 21.2946 - val_loss: 2.7400 - val_mape: 13.9409
# Epoch 84/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0542 - mape: 21.7861 - val_loss: 2.6182 - val_mape: 13.1687
# Epoch 85/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7557 - mape: 19.5529 - val_loss: 2.7841 - val_mape: 14.1426
# Epoch 86/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6506 - mape: 19.1451 - val_loss: 2.5392 - val_mape: 12.6369
# Epoch 87/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5235 - mape: 18.4813 - val_loss: 2.5941 - val_mape: 12.8936
# Epoch 88/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7050 - mape: 19.9247 - val_loss: 2.6527 - val_mape: 13.0584
# Epoch 89/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6197 - mape: 18.6080 - val_loss: 2.3289 - val_mape: 10.9848
# Epoch 90/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2498 - mape: 16.8521 - val_loss: 2.8771 - val_mape: 14.4124
# Epoch 91/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5463 - mape: 18.4760 - val_loss: 2.4038 - val_mape: 11.6154
# Epoch 92/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1025 - mape: 16.2770 - val_loss: 2.4644 - val_mape: 12.1516
# Epoch 93/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3383 - mape: 17.4569 - val_loss: 2.6289 - val_mape: 13.0653
# Epoch 94/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3815 - mape: 17.6610 - val_loss: 2.7132 - val_mape: 13.6612
# Epoch 95/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2513 - mape: 17.4822 - val_loss: 2.6597 - val_mape: 12.8418
# Epoch 96/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2388 - mape: 16.6852 - val_loss: 2.3130 - val_mape: 10.8616
# Epoch 97/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1644 - mape: 16.1614 - val_loss: 2.3273 - val_mape: 10.9134
# Epoch 98/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3080 - mape: 16.7552 - val_loss: 2.3910 - val_mape: 11.7896
# Epoch 99/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2062 - mape: 16.3315 - val_loss: 2.1766 - val_mape: 10.1807
# Epoch 100/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1463 - mape: 16.1785 - val_loss: 2.2073 - val_mape: 10.3230
# Epoch 101/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1884 - mape: 16.5640 - val_loss: 2.3813 - val_mape: 11.0164
# Epoch 102/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1976 - mape: 16.1107 - val_loss: 2.1761 - val_mape: 10.1883
# Epoch 103/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1357 - mape: 16.4274 - val_loss: 2.5017 - val_mape: 12.4421
# Epoch 104/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1462 - mape: 16.3845 - val_loss: 2.6970 - val_mape: 12.7025
# Epoch 105/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2912 - mape: 16.6970 - val_loss: 2.8074 - val_mape: 13.3596
# Epoch 106/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2836 - mape: 16.5808 - val_loss: 2.7041 - val_mape: 13.3047
# Epoch 107/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0724 - mape: 16.1524 - val_loss: 2.3968 - val_mape: 11.4132
# Epoch 108/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3722 - mape: 17.3198 - val_loss: 2.3801 - val_mape: 11.2573
# Epoch 109/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0576 - mape: 15.8489 - val_loss: 2.6150 - val_mape: 12.3165
# Epoch 110/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0790 - mape: 15.9701 - val_loss: 2.5970 - val_mape: 11.4611
# Epoch 111/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0319 - mape: 15.7872 - val_loss: 2.3770 - val_mape: 10.7095
# Epoch 112/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1598 - mape: 16.3827 - val_loss: 2.2755 - val_mape: 10.5408
# Epoch 113/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0493 - mape: 16.0645 - val_loss: 2.6366 - val_mape: 12.4514
# Epoch 114/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0684 - mape: 15.6546 - val_loss: 2.6412 - val_mape: 12.4706
# Epoch 115/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0216 - mape: 15.7963 - val_loss: 2.7594 - val_mape: 12.7574
# Epoch 116/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9976 - mape: 15.6730 - val_loss: 2.7948 - val_mape: 12.9118
# Epoch 117/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0447 - mape: 16.0704 - val_loss: 2.6741 - val_mape: 12.7307
# Epoch 118/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1830 - mape: 16.3304 - val_loss: 2.6495 - val_mape: 12.8065
# Epoch 119/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1237 - mape: 16.4159 - val_loss: 2.8053 - val_mape: 12.9603
# Epoch 120/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9908 - mape: 15.5067 - val_loss: 2.4999 - val_mape: 11.5574
# Epoch 121/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9426 - mape: 15.1406 - val_loss: 2.4440 - val_mape: 12.1017
# Epoch 122/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1071 - mape: 16.1467 - val_loss: 2.2768 - val_mape: 10.9072
# Epoch 123/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8231 - mape: 14.8046 - val_loss: 2.1993 - val_mape: 9.8284
# Epoch 124/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2519 - mape: 16.3308 - val_loss: 2.2045 - val_mape: 9.9972
# Epoch 125/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9087 - mape: 15.1789 - val_loss: 2.2457 - val_mape: 10.4441
# Epoch 126/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9405 - mape: 15.1474 - val_loss: 2.2502 - val_mape: 10.9630
# Epoch 127/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0110 - mape: 15.8804 - val_loss: 2.3119 - val_mape: 10.5674
# Epoch 128/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9333 - mape: 15.2665 - val_loss: 2.5142 - val_mape: 11.3100
# Epoch 129/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9441 - mape: 15.5650 - val_loss: 2.6327 - val_mape: 13.0153
# Epoch 130/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9945 - mape: 15.3427 - val_loss: 2.7011 - val_mape: 13.3407
# Epoch 131/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9845 - mape: 15.7902 - val_loss: 2.5677 - val_mape: 12.8738
# Epoch 132/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9724 - mape: 15.6246 - val_loss: 2.4167 - val_mape: 11.4548
# Epoch 133/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0797 - mape: 15.9882 - val_loss: 2.7252 - val_mape: 12.5997
# Epoch 134/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8638 - mape: 14.9702 - val_loss: 2.6395 - val_mape: 12.3905
# Epoch 135/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9201 - mape: 15.2513 - val_loss: 2.4891 - val_mape: 11.2790
# Epoch 136/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.9349 - mape: 15.4031 - val_loss: 2.3827 - val_mape: 10.8283
# Epoch 137/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8758 - mape: 15.1244 - val_loss: 2.2420 - val_mape: 10.4437
# Epoch 138/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9388 - mape: 15.0345 - val_loss: 2.2710 - val_mape: 10.6001
# Epoch 139/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8422 - mape: 14.6955 - val_loss: 2.3152 - val_mape: 11.0768
# Epoch 140/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1705 - mape: 16.7954 - val_loss: 2.5373 - val_mape: 12.1643
# Epoch 141/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6738 - mape: 14.3079 - val_loss: 2.7313 - val_mape: 13.2704
# Epoch 142/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9887 - mape: 16.0420 - val_loss: 2.6292 - val_mape: 12.9796
# Epoch 143/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8391 - mape: 14.9173 - val_loss: 2.5975 - val_mape: 12.0998
# Epoch 144/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8582 - mape: 14.8272 - val_loss: 2.4847 - val_mape: 11.0449
# Epoch 145/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8076 - mape: 14.4677 - val_loss: 2.3726 - val_mape: 10.7023
# Epoch 146/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7869 - mape: 14.6114 - val_loss: 2.3317 - val_mape: 10.6516
# Epoch 147/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8167 - mape: 14.5100 - val_loss: 2.3871 - val_mape: 10.9181
# Epoch 148/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6693 - mape: 13.6898 - val_loss: 2.5601 - val_mape: 11.4901
# Epoch 149/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5904 - mape: 13.4123 - val_loss: 2.3060 - val_mape: 10.6664
# Epoch 150/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7623 - mape: 14.4271 - val_loss: 2.3471 - val_mape: 10.5493
# Epoch 151/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7109 - mape: 13.9895 - val_loss: 2.5126 - val_mape: 11.1844
# Epoch 152/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7416 - mape: 14.0315 - val_loss: 2.5565 - val_mape: 11.5803
# Epoch 153/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5387 - mape: 13.4532 - val_loss: 2.3883 - val_mape: 10.8906
# Epoch 154/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6743 - mape: 14.0127 - val_loss: 2.3607 - val_mape: 10.9884
# Epoch 155/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7463 - mape: 14.5248 - val_loss: 2.8419 - val_mape: 13.9219
# Epoch 156/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6275 - mape: 14.0422 - val_loss: 2.7590 - val_mape: 12.8214
# Epoch 157/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5727 - mape: 13.4004 - val_loss: 3.0717 - val_mape: 14.8398
# Epoch 158/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7337 - mape: 13.7679 - val_loss: 3.2761 - val_mape: 16.0877
# Epoch 159/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8006 - mape: 14.2877 - val_loss: 3.0494 - val_mape: 14.6787
# Epoch 160/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5532 - mape: 13.2599 - val_loss: 2.8620 - val_mape: 13.8833
# Epoch 161/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7410 - mape: 13.7398 - val_loss: 3.0903 - val_mape: 15.1486
# Epoch 162/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6958 - mape: 13.8381 - val_loss: 2.7166 - val_mape: 12.8540
# Epoch 163/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7412 - mape: 13.9009 - val_loss: 2.5171 - val_mape: 12.0726
# Epoch 164/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5558 - mape: 12.9586 - val_loss: 2.5073 - val_mape: 12.0174
# Epoch 165/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7560 - mape: 13.9598 - val_loss: 2.5176 - val_mape: 11.7087
# Epoch 166/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8118 - mape: 14.1386 - val_loss: 2.7488 - val_mape: 12.9970
# Epoch 167/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8355 - mape: 14.8870 - val_loss: 3.0792 - val_mape: 15.4019
# Epoch 168/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6842 - mape: 13.7168 - val_loss: 2.9578 - val_mape: 14.5177
# Epoch 169/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6507 - mape: 13.7066 - val_loss: 2.5775 - val_mape: 12.2387
# Epoch 170/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3018 - mape: 11.9065 - val_loss: 2.3948 - val_mape: 11.0954
# Epoch 171/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4738 - mape: 12.2717 - val_loss: 2.2162 - val_mape: 10.4229
# Epoch 172/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3928 - mape: 12.4865 - val_loss: 2.3142 - val_mape: 10.7819
# Epoch 173/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5411 - mape: 12.6103 - val_loss: 2.7274 - val_mape: 12.9893
# Epoch 174/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5776 - mape: 13.3588 - val_loss: 2.7725 - val_mape: 13.1248
# Epoch 175/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5403 - mape: 13.4089 - val_loss: 2.6267 - val_mape: 12.2420
# Epoch 176/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7129 - mape: 13.8481 - val_loss: 2.6285 - val_mape: 12.1842
# Epoch 177/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6828 - mape: 14.1136 - val_loss: 2.6065 - val_mape: 11.7280
# Epoch 178/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6197 - mape: 13.0684 - val_loss: 2.5516 - val_mape: 11.8256
# Epoch 179/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4256 - mape: 12.4598 - val_loss: 2.6684 - val_mape: 12.6428
# Epoch 180/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6859 - mape: 14.0585 - val_loss: 2.6718 - val_mape: 12.6271
# Epoch 181/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6869 - mape: 14.7973 - val_loss: 2.6153 - val_mape: 12.3778
# Epoch 182/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6675 - mape: 14.0144 - val_loss: 2.5681 - val_mape: 11.8138
# Epoch 183/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6640 - mape: 13.0287 - val_loss: 2.5013 - val_mape: 11.4661
# Epoch 184/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3706 - mape: 12.2388 - val_loss: 2.2936 - val_mape: 10.8713
# Epoch 185/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5167 - mape: 12.9397 - val_loss: 2.3303 - val_mape: 11.0707
# Epoch 186/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7105 - mape: 14.1075 - val_loss: 2.2396 - val_mape: 10.2641
# Epoch 187/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5836 - mape: 13.3321 - val_loss: 2.5008 - val_mape: 11.1309
# Epoch 188/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4302 - mape: 12.2268 - val_loss: 2.4065 - val_mape: 10.9194
# Epoch 189/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4242 - mape: 11.8879 - val_loss: 2.5473 - val_mape: 11.6184
# Epoch 190/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3581 - mape: 12.0920 - val_loss: 2.3892 - val_mape: 11.1732
# Epoch 191/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3708 - mape: 11.6919 - val_loss: 2.3777 - val_mape: 11.0246
# Epoch 192/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5069 - mape: 13.2110 - val_loss: 2.4272 - val_mape: 11.0869
# Epoch 193/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3802 - mape: 12.4210 - val_loss: 2.3458 - val_mape: 11.0190
# Epoch 194/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4801 - mape: 13.0611 - val_loss: 2.2765 - val_mape: 10.5512
# Epoch 195/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3526 - mape: 12.2111 - val_loss: 2.4099 - val_mape: 10.8496
# Epoch 196/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4103 - mape: 12.3632 - val_loss: 2.3710 - val_mape: 10.8249
# Epoch 197/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3464 - mape: 11.9885 - val_loss: 2.4067 - val_mape: 11.0191
# Epoch 198/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3173 - mape: 11.9489 - val_loss: 2.3611 - val_mape: 10.9852
# Epoch 199/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4686 - mape: 12.9386 - val_loss: 2.2767 - val_mape: 10.6163
# Epoch 200/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4391 - mape: 12.0877 - val_loss: 2.2957 - val_mape: 10.5637
# Epoch 201/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3737 - mape: 12.1074 - val_loss: 2.2827 - val_mape: 10.5460
# Epoch 202/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3463 - mape: 12.2375 - val_loss: 2.2821 - val_mape: 10.6503
# Epoch 203/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3057 - mape: 12.1811 - val_loss: 2.2507 - val_mape: 10.5510
# Epoch 204/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2811 - mape: 11.3987 - val_loss: 2.3864 - val_mape: 10.8617
# Epoch 205/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4221 - mape: 12.1446 - val_loss: 2.2743 - val_mape: 10.3991
# Epoch 206/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3696 - mape: 11.6614 - val_loss: 2.3951 - val_mape: 11.1355
# Epoch 207/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4441 - mape: 12.5608 - val_loss: 2.5035 - val_mape: 11.8470
# Epoch 208/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5521 - mape: 13.0108 - val_loss: 2.5088 - val_mape: 11.4996
# Epoch 209/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4639 - mape: 12.6013 - val_loss: 2.4864 - val_mape: 11.0395
# Epoch 210/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3683 - mape: 11.7453 - val_loss: 2.3955 - val_mape: 10.9124
# Epoch 211/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3707 - mape: 11.8597 - val_loss: 2.3474 - val_mape: 10.8814
# Epoch 212/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2791 - mape: 11.6575 - val_loss: 2.3250 - val_mape: 10.7346
# Epoch 213/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3632 - mape: 11.4205 - val_loss: 2.4181 - val_mape: 10.9629
# Epoch 214/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2327 - mape: 10.7551 - val_loss: 2.3184 - val_mape: 10.7371
# Epoch 215/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3099 - mape: 11.1801 - val_loss: 2.3132 - val_mape: 10.7627
# Epoch 216/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4639 - mape: 11.9332 - val_loss: 2.4643 - val_mape: 11.4454
# Epoch 217/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3071 - mape: 11.5079 - val_loss: 2.6193 - val_mape: 12.3815
# Epoch 218/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1520 - mape: 10.4871 - val_loss: 2.4319 - val_mape: 11.5723
# Epoch 219/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4939 - mape: 12.2102 - val_loss: 2.4722 - val_mape: 11.8088
# Epoch 220/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3828 - mape: 11.6153 - val_loss: 2.6733 - val_mape: 12.3883
# Epoch 221/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2323 - mape: 10.9122 - val_loss: 2.5733 - val_mape: 12.1381
# Epoch 222/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2309 - mape: 11.2679 - val_loss: 2.5078 - val_mape: 12.0407
# Epoch 223/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2396 - mape: 11.3648 - val_loss: 2.4832 - val_mape: 11.8231
# Epoch 224/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3491 - mape: 11.7302 - val_loss: 2.4921 - val_mape: 11.7443
# Epoch 225/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3690 - mape: 12.4297 - val_loss: 2.3885 - val_mape: 10.9843
# Epoch 226/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2425 - mape: 11.4327 - val_loss: 2.3792 - val_mape: 10.9748
# Epoch 227/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4290 - mape: 12.0727 - val_loss: 2.3442 - val_mape: 10.7544
# Epoch 228/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2979 - mape: 11.4109 - val_loss: 2.5289 - val_mape: 11.4256
# Epoch 229/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3408 - mape: 11.3843 - val_loss: 2.4421 - val_mape: 11.1139
# Epoch 230/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2552 - mape: 11.3365 - val_loss: 2.4532 - val_mape: 11.0380
# Epoch 231/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3152 - mape: 11.0335 - val_loss: 2.3636 - val_mape: 10.7680
# Epoch 232/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2166 - mape: 10.6411 - val_loss: 2.3217 - val_mape: 10.5783
# Epoch 233/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2696 - mape: 11.7469 - val_loss: 2.5135 - val_mape: 11.1624
# Epoch 234/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2401 - mape: 10.9748 - val_loss: 2.3455 - val_mape: 10.8063
# Epoch 235/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1761 - mape: 10.7056 - val_loss: 2.4536 - val_mape: 11.1956
# Epoch 236/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3958 - mape: 11.5319 - val_loss: 2.6018 - val_mape: 12.2669
# Epoch 237/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1541 - mape: 10.5877 - val_loss: 2.5780 - val_mape: 12.1638
# Epoch 238/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3172 - mape: 11.9860 - val_loss: 2.4977 - val_mape: 11.4938
# Epoch 239/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0277 - mape: 9.9263 - val_loss: 2.3929 - val_mape: 10.9429
# Epoch 240/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2205 - mape: 10.9876 - val_loss: 2.3947 - val_mape: 11.0694
# Epoch 241/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2437 - mape: 11.1988 - val_loss: 2.4141 - val_mape: 11.0766
# Epoch 242/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3266 - mape: 11.6521 - val_loss: 2.4883 - val_mape: 11.5548
# Epoch 243/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3303 - mape: 11.3549 - val_loss: 2.4654 - val_mape: 11.1590
# Epoch 244/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4537 - mape: 12.8939 - val_loss: 2.4035 - val_mape: 11.0230
# Epoch 245/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0742 - mape: 10.0988 - val_loss: 2.3585 - val_mape: 11.0320
# Epoch 246/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2026 - mape: 10.7771 - val_loss: 2.3765 - val_mape: 11.0693
# Epoch 247/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3170 - mape: 11.8988 - val_loss: 2.4254 - val_mape: 11.1454
# Epoch 248/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4317 - mape: 12.2715 - val_loss: 2.6907 - val_mape: 12.3708
# Epoch 249/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2947 - mape: 11.2787 - val_loss: 2.6693 - val_mape: 11.8643
# Epoch 250/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1689 - mape: 11.0668 - val_loss: 2.5252 - val_mape: 11.1765
# Epoch 251/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0677 - mape: 10.1936 - val_loss: 2.5030 - val_mape: 11.1252
# Epoch 252/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1766 - mape: 10.3273 - val_loss: 2.5276 - val_mape: 11.4329
# Epoch 253/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1163 - mape: 10.3800 - val_loss: 2.7409 - val_mape: 12.7706
# Epoch 254/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2020 - mape: 11.1521 - val_loss: 2.7211 - val_mape: 12.3555
# Epoch 255/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2617 - mape: 10.7683 - val_loss: 2.4416 - val_mape: 11.0696
# Epoch 256/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1767 - mape: 10.6301 - val_loss: 2.4689 - val_mape: 11.3132
# Epoch 257/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1772 - mape: 10.6352 - val_loss: 2.5334 - val_mape: 11.5732
# Epoch 258/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1992 - mape: 11.1575 - val_loss: 2.4886 - val_mape: 11.4551
# Epoch 259/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1527 - mape: 10.9795 - val_loss: 2.6371 - val_mape: 12.4495
# Epoch 260/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2107 - mape: 10.4846 - val_loss: 2.6053 - val_mape: 12.0820
# Epoch 261/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1372 - mape: 10.3525 - val_loss: 2.6196 - val_mape: 12.1392
# Epoch 262/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1385 - mape: 10.2170 - val_loss: 2.5825 - val_mape: 12.0754
# Epoch 263/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0779 - mape: 10.2553 - val_loss: 2.4429 - val_mape: 11.4098
# Epoch 264/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1410 - mape: 10.4494 - val_loss: 2.4117 - val_mape: 11.1052
# Epoch 265/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2540 - mape: 11.1369 - val_loss: 2.4500 - val_mape: 11.2364
# Epoch 266/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0019 - mape: 9.8975 - val_loss: 2.5674 - val_mape: 12.4353
# Epoch 267/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1046 - mape: 10.7404 - val_loss: 2.6354 - val_mape: 12.6323
# Epoch 268/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3484 - mape: 12.2100 - val_loss: 2.6631 - val_mape: 12.4678
# Epoch 269/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1550 - mape: 10.7160 - val_loss: 2.4081 - val_mape: 11.0897
# Epoch 270/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2706 - mape: 11.0771 - val_loss: 2.4263 - val_mape: 11.2253
# Epoch 271/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0788 - mape: 10.2938 - val_loss: 2.5432 - val_mape: 12.1298
# Epoch 272/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3806 - mape: 12.4648 - val_loss: 2.5871 - val_mape: 11.7462
# Epoch 273/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2272 - mape: 11.2031 - val_loss: 2.5401 - val_mape: 11.4607
# Epoch 274/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0954 - mape: 10.2320 - val_loss: 2.5046 - val_mape: 11.3371
# Epoch 275/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9980 - mape: 10.1497 - val_loss: 2.3168 - val_mape: 10.6873
# Epoch 276/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1653 - mape: 10.5845 - val_loss: 2.3932 - val_mape: 10.8945
# Epoch 277/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2135 - mape: 11.0134 - val_loss: 2.6328 - val_mape: 11.6469
# Epoch 278/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0826 - mape: 9.9167 - val_loss: 2.4787 - val_mape: 11.2648
# Epoch 279/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0863 - mape: 10.1083 - val_loss: 2.3651 - val_mape: 11.0105
# Epoch 280/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1134 - mape: 10.1672 - val_loss: 2.4258 - val_mape: 11.1105
# Epoch 281/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0113 - mape: 9.8247 - val_loss: 2.4160 - val_mape: 11.0321
# Epoch 282/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9604 - mape: 9.6565 - val_loss: 2.5052 - val_mape: 11.4122
# Epoch 283/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1851 - mape: 10.7631 - val_loss: 2.4435 - val_mape: 11.2746
# Epoch 284/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0119 - mape: 9.8164 - val_loss: 2.4905 - val_mape: 11.8503
# Epoch 285/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1104 - mape: 10.4177 - val_loss: 2.3278 - val_mape: 10.7818
# Epoch 286/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0413 - mape: 9.7988 - val_loss: 2.3390 - val_mape: 10.8421
# Epoch 287/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0867 - mape: 10.1979 - val_loss: 2.3973 - val_mape: 11.1985
# Epoch 288/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0679 - mape: 10.1316 - val_loss: 2.5322 - val_mape: 11.8945
# Epoch 289/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3626 - mape: 11.7456 - val_loss: 2.6102 - val_mape: 12.2355
# Epoch 290/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0678 - mape: 9.9612 - val_loss: 2.5881 - val_mape: 12.3935
# Epoch 291/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1627 - mape: 10.4763 - val_loss: 2.5959 - val_mape: 12.4920
# Epoch 292/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0150 - mape: 9.9292 - val_loss: 2.6812 - val_mape: 12.7107
# Epoch 293/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9975 - mape: 10.0542 - val_loss: 2.6174 - val_mape: 12.1893
# Epoch 294/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0244 - mape: 9.7784 - val_loss: 2.5301 - val_mape: 11.9225
# Epoch 295/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9706 - mape: 9.7688 - val_loss: 2.5519 - val_mape: 11.9646
# Epoch 296/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0001 - mape: 9.8936 - val_loss: 2.6488 - val_mape: 12.3956
# Epoch 297/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2834 - mape: 12.0576 - val_loss: 2.6086 - val_mape: 12.1647
# Epoch 298/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1388 - mape: 10.7723 - val_loss: 2.7233 - val_mape: 12.6860
# Epoch 299/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1756 - mape: 10.8878 - val_loss: 2.7314 - val_mape: 12.8417
# Epoch 300/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2481 - mape: 11.1870 - val_loss: 2.7005 - val_mape: 12.8169

# %% [markdown]
# + loss
# Training loss, the error the model makes on the training data after each epoch
# Helps model adjust its weights to minimize the difference btwn predicted and actual values
# + val_loss
# How well model acts on unseen data
# + mape
# Mean Absolute %age Error btwn actual and predicted values
# + val_mape

# %%
history_df = pd.DataFrame(history.history)
history_df.tail()

# history.history is a dictionary where the keys are the names of the metrics (e.g., 'loss', 'val_loss')
# history.history['loss'] has training loss values for each epoch
# Out:
#          loss       mape  val_loss   val_mape
# 295  2.036565  10.098140  2.648753  12.395566
# 296  2.144668  11.131507  2.608582  12.164681
# 297  2.165480  10.831223  2.723316  12.685978
# 298  2.141816  10.737486  2.731441  12.841676
# 299  2.144287  10.764146  2.700477  12.816947

# %%
history_df.loc[:, ['loss', 'val_loss']].plot(xlabel='epochs') # all rows, loss and val_loss columns
history_df.loc[:, ['mape', 'val_mape']].plot(xlabel='epochs') # all rows, mape and val_mape columns
plt.show()
